# %% [markdown]
# <a href="https://colab.research.google.com/github/Koussailakadi/Speech_Input_for_Emotion_Recognition/blob/main/emotion_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import sys
print("path: ",os.getcwd())


# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
import IPython.display as ipd
import numpy as np 
import pandas as pd


from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
# Out:
# path:  /content

# %%
#load data:
path_data=r"/content/drive/MyDrive/data.zip"

from zipfile import ZipFile
# !unzip '/content/drive/MyDrive/data.zip'
# Out:
# Archive:  /content/drive/MyDrive/data.zip
#    creating: data/
#   inflating: data/Features.npy
#   inflating: data/labels.npy

# %%
try:
  del Features
  del Labels
  del x_train
  del x_test
  del y_train
  del y_test
except:
  pass
  
Features=np.load("/content/data/Features.npy")
Labels=np.load("/content/data/labels.npy")

# %%
# As this is a multiclass classification problem onehotencoding our Y.
encoder = OneHotEncoder()
Labels = encoder.fit_transform(np.array(Labels).reshape(-1,1)).toarray()
print(Labels.shape)
print(Features.shape)
# Out:
# (3170, 2)
# (3170, 80000)

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(Features, Labels, random_state=0, shuffle=True)
print("x_train:{} , y_train:{} , x_test:{} ,y_test:{}".format(x_train.shape, y_train.shape, x_test.shape, y_test.shape))
# Out:
# x_train:(2377, 80000) , y_train:(2377, 2) , x_test:(793, 80000) ,y_test:(793, 2)

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
print("x_train:{} , y_train:{} , x_test:{} ,y_test:{}".format(x_train.shape, y_train.shape, x_test.shape, y_test.shape))
# Out:
# x_train:(2377, 80000) , y_train:(2377, 2) , x_test:(793, 80000) ,y_test:(793, 2)

# %%
# making our data compatible to model.
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)

y_train = np.expand_dims(y_train, axis=1)
y_test = np.expand_dims(y_test, axis=1)
print("x_train:{} , y_train:{} , x_test:{} ,y_test:{}".format(x_train.shape, y_train.shape, x_test.shape, y_test.shape))
# Out:
# x_train:(2377, 80000, 1) , y_train:(2377, 1, 2) , x_test:(793, 80000, 1) ,y_test:(793, 1, 2)

# %%
import sys
import tensorflow as tf
from tensorflow import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Model
from keras.layers import Dense, Conv1D, Conv2D, MaxPooling1D, Flatten, Dropout, BatchNormalization, Activation , Add , Input, TimeDistributed, GlobalAveragePooling1D
from keras.callbacks import ModelCheckpoint
from keras import activations

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning) 


#Résidual bloc:
def block(inputs, filters, kernel_size, strides):
    #apply conv1D:
    fx = Conv1D(filters, kernel_size, strides , padding='same')(inputs)

    #apply a batchnormalization to an input tensor:
    fx = BatchNormalization()(fx)
    
    #apply a rulu functgion to batch normalized tensor
    fx = Activation(activations.relu)(fx)
     
    return fx


#Résidual blocs:
def resnet_block(inputs, filters, kernel_size=3, stride=3):
    #bloc 1:
    fx = block(inputs, filters, kernel_size, strides=stride)
    
    #bloc 2:
    fx = block(fx, filters, kernel_size, strides=1)
    
    #bloc 3:
    fx = block(fx, filters, kernel_size, strides=1)
    
    #skip connection:
    skip_x = Conv1D(filters, kernel_size, strides=stride , padding ='same')(inputs)

    #apply a batchnormalization to an input tensor:
    skip_x = BatchNormalization()(skip_x)
    
    #add layer:
    out= Add()([fx,skip_x])
    
    #relu:
    out = Activation(activations.relu)(out)
        
    return out



def Resnet(input_shape=(80000,1)):
    
    x_input=Input(shape=input_shape)
    #stag 1:
    x=Conv1D(filters=128, kernel_size=3, strides=3)(x_input)
    x=BatchNormalization()(x)
    x=Activation(activations.relu)(x)

    #resnets blocs:
    x=resnet_block(x, filters=128, kernel_size=3, stride=3)
    x=resnet_block(x, filters=256, kernel_size=3, stride=3)
    x=resnet_block(x, filters=256, kernel_size=3, stride=3)
    x=resnet_block(x, filters=256, kernel_size=3, stride=3)
    x=resnet_block(x, filters=512, kernel_size=3, stride=3)
    x=resnet_block(x, filters=512, kernel_size=3, stride=3)
    x=resnet_block(x, filters=512, kernel_size=3, stride=3)
    
    #conv2:
    x=Conv1D(filters=768, kernel_size=3, strides=1)(x)
    x=BatchNormalization()(x)
    x=Activation(activations.relu)(x)
    
    #dense layers: 
    x=Dropout(rate=0.5, noise_shape=None)(x)
    dense_layer_1=Dense(768,activation=activations.relu)
    x=TimeDistributed(dense_layer_1)(x)
    dense_layer_2=Dense(2)
    x=TimeDistributed(dense_layer_2)(x)
    x=GlobalAveragePooling1D(keepdims=True)(x)
    x=Activation(activations.softmax)(x)
    #model
    model= Model(x_input, x, name='Rasnet')
    
    return model
  
#inputs:
inputs=x_train.shape
model=Resnet()

# initiate Adam optimizer
opt = keras.optimizers.Adam(learning_rate=0.01)

# Let's train the model using RMSprop
model.compile(loss='binary_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "Rasnet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 80000, 1)]   0           []
#
#  conv1d (Conv1D)                (None, 26666, 128)   512         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 26666, 128)  512         ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 26666, 128)   0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 8889, 128)    49280       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 8889, 128)   512         ['conv1d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 8889, 128)    0           ['batch_normalization_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 8889, 128)    49280       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8889, 128)   512         ['conv1d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 8889, 128)    0           ['batch_normalization_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 8889, 128)    49280       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8889, 128)   512         ['conv1d_3[0][0]']
#  rmalization)
#
#  conv1d_4 (Conv1D)              (None, 8889, 128)    49280       ['activation[0][0]']
#
#  activation_3 (Activation)      (None, 8889, 128)    0           ['batch_normalization_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8889, 128)   512         ['conv1d_4[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 8889, 128)    0           ['activation_3[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_4 (Activation)      (None, 8889, 128)    0           ['add[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 2963, 256)    98560       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 2963, 256)   1024        ['conv1d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 2963, 256)    0           ['batch_normalization_5[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 2963, 256)    196864      ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 2963, 256)   1024        ['conv1d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 2963, 256)    0           ['batch_normalization_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 2963, 256)    196864      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 2963, 256)   1024        ['conv1d_7[0][0]']
#  rmalization)
#
#  conv1d_8 (Conv1D)              (None, 2963, 256)    98560       ['activation_4[0][0]']
#
#  activation_7 (Activation)      (None, 2963, 256)    0           ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 2963, 256)   1024        ['conv1d_8[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 2963, 256)    0           ['activation_7[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_8 (Activation)      (None, 2963, 256)    0           ['add_1[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 988, 256)     196864      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 988, 256)    1024        ['conv1d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 988, 256)     0           ['batch_normalization_9[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 988, 256)     196864      ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 988, 256)    1024        ['conv1d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 988, 256)     0           ['batch_normalization_10[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 988, 256)     196864      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 988, 256)    1024        ['conv1d_11[0][0]']
#  ormalization)
#
#  conv1d_12 (Conv1D)             (None, 988, 256)     196864      ['activation_8[0][0]']
#
#  activation_11 (Activation)     (None, 988, 256)     0           ['batch_normalization_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 988, 256)    1024        ['conv1d_12[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 988, 256)     0           ['activation_11[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_12 (Activation)     (None, 988, 256)     0           ['add_2[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 330, 256)     196864      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 330, 256)    1024        ['conv1d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 330, 256)     0           ['batch_normalization_13[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 330, 256)     196864      ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 330, 256)    1024        ['conv1d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 330, 256)     0           ['batch_normalization_14[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 330, 256)     196864      ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 330, 256)    1024        ['conv1d_15[0][0]']
#  ormalization)
#
#  conv1d_16 (Conv1D)             (None, 330, 256)     196864      ['activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 330, 256)     0           ['batch_normalization_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 330, 256)    1024        ['conv1d_16[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 330, 256)     0           ['activation_15[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_16 (Activation)     (None, 330, 256)     0           ['add_3[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 110, 512)     393728      ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 110, 512)    2048        ['conv1d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 110, 512)     0           ['batch_normalization_17[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 110, 512)     786944      ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 110, 512)    2048        ['conv1d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 110, 512)     0           ['batch_normalization_18[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 110, 512)     786944      ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 110, 512)    2048        ['conv1d_19[0][0]']
#  ormalization)
#
#  conv1d_20 (Conv1D)             (None, 110, 512)     393728      ['activation_16[0][0]']
#
#  activation_19 (Activation)     (None, 110, 512)     0           ['batch_normalization_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 110, 512)    2048        ['conv1d_20[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 110, 512)     0           ['activation_19[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_20 (Activation)     (None, 110, 512)     0           ['add_4[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 37, 512)      786944      ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 37, 512)     2048        ['conv1d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 37, 512)      0           ['batch_normalization_21[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 37, 512)      786944      ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 37, 512)     2048        ['conv1d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 37, 512)      0           ['batch_normalization_22[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 37, 512)      786944      ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 37, 512)     2048        ['conv1d_23[0][0]']
#  ormalization)
#
#  conv1d_24 (Conv1D)             (None, 37, 512)      786944      ['activation_20[0][0]']
#
#  activation_23 (Activation)     (None, 37, 512)      0           ['batch_normalization_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 37, 512)     2048        ['conv1d_24[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 37, 512)      0           ['activation_23[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_24 (Activation)     (None, 37, 512)      0           ['add_5[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 13, 512)      786944      ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 13, 512)     2048        ['conv1d_25[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 13, 512)      0           ['batch_normalization_25[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 13, 512)      786944      ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 13, 512)     2048        ['conv1d_26[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 13, 512)      0           ['batch_normalization_26[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 13, 512)      786944      ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 13, 512)     2048        ['conv1d_27[0][0]']
#  ormalization)
#
#  conv1d_28 (Conv1D)             (None, 13, 512)      786944      ['activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 13, 512)      0           ['batch_normalization_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 13, 512)     2048        ['conv1d_28[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 13, 512)      0           ['activation_27[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_28 (Activation)     (None, 13, 512)      0           ['add_6[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 11, 768)      1180416     ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 11, 768)     3072        ['conv1d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 11, 768)      0           ['batch_normalization_29[0][0]']
#
#  dropout (Dropout)              (None, 11, 768)      0           ['activation_29[0][0]']
#
#  time_distributed (TimeDistribu  (None, 11, 768)     590592      ['dropout[0][0]']
#  ted)
#
#  time_distributed_1 (TimeDistri  (None, 11, 2)       1538        ['time_distributed[0][0]']
#  buted)
#
#  global_average_pooling1d (Glob  (None, 1, 2)        0           ['time_distributed_1[0][0]']
#  alAveragePooling1D)
#
#  activation_30 (Activation)     (None, 1, 2)         0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 12,835,330
# Trainable params: 12,814,082
# Non-trainable params: 21,248
# __________________________________________________________________________________________________

# %%
epochs=10
batch_size=32

# Fit the model
history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test,y_test),
              shuffle=True)
              
print("fin d'entrainement")
# Out:
# Epoch 1/10
# 75/75 [==============================] - 139s 2s/step - loss: 0.4464 - accuracy: 0.7535 - val_loss: 0.3546 - val_accuracy: 0.8714
# Epoch 2/10
# 75/75 [==============================] - 118s 2s/step - loss: 0.1454 - accuracy: 0.9466 - val_loss: 0.6218 - val_accuracy: 0.8222
# Epoch 3/10
# 75/75 [==============================] - 118s 2s/step - loss: 0.0873 - accuracy: 0.9676 - val_loss: 0.1875 - val_accuracy: 0.9433
# Epoch 4/10
# 75/75 [==============================] - 118s 2s/step - loss: 0.0781 - accuracy: 0.9684 - val_loss: 0.1893 - val_accuracy: 0.9445
# Epoch 5/10
# 75/75 [==============================] - 118s 2s/step - loss: 0.0746 - accuracy: 0.9756 - val_loss: 0.6386 - val_accuracy: 0.8272
# Epoch 6/10
# 75/75 [==============================] - 118s 2s/step - loss: 0.0513 - accuracy: 0.9823 - val_loss: 0.3250 - val_accuracy: 0.9130
# Epoch 7/10
# 75/75 [==============================] - 118s 2s/step - loss: 0.0453 - accuracy: 0.9870 - val_loss: 0.5691 - val_accuracy: 0.8638
# Epoch 8/10
# 75/75 [==============================] - 118s 2s/step - loss: 0.0238 - accuracy: 0.9928 - val_loss: 0.0374 - val_accuracy: 0.9874
# Epoch 9/10
# 75/75 [==============================] - 118s 2s/step - loss: 0.0473 - accuracy: 0.9853 - val_loss: 0.0249 - val_accuracy: 0.9924
# Epoch 10/10
# 75/75 [==============================] - 118s 2s/step - loss: 0.0266 - accuracy: 0.9907 - val_loss: 2.9537 - val_accuracy: 0.6986
# fin d'entrainement

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model.save('/content/drive/MyDrive/my_model.h5')  # creates a HDF5 file 'my_model.h5'

del model  # deletes the existing model
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
from keras.models import load_model
model = load_model('/content/drive/MyDrive/my_model.h5')

# %%
tf.keras.utils.plot_model(
    model,
    to_file="model.png",
    show_shapes=False,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
)
